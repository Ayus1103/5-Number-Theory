# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
lst_marks=[45,32,56,75,89,54,32,89,90,87,67,54,45,98,99,67,74]
minimum,Q1,medan,Q3,maximum=np.quantile(lst_marks,[0,0.25,0.50,0.75,1.0])

# %%
minimum,Q1,medan,Q3,maximum
# Out:
# (np.float64(32.0),
#  np.float64(54.0),
#  np.float64(67.0),
#  np.float64(89.0),
#  np.float64(99.0))

# %%
IQR=Q3-Q1
IQR
# Out:
# np.float64(35.0)

# %%
lower_fence=Q1-1.5*(IQR)
higher_fence=Q3+1.5*(IQR)

# %%
print(lower_fence)
print(higher_fence)
# Out:
# 1.5
# 141.5

# %%
sns.boxplot(lst_marks)
plt.savefig("without_outliers.jpg", dpi=300)

# %%
lst_marks=[-50,-60,45,32,56,75,89,54,32,89,90,87,67,54,45,98,99,67,74,150,170]

# %%
sns.boxplot(lst_marks)
plt.savefig("with_outliers.jpg", dpi=300)
